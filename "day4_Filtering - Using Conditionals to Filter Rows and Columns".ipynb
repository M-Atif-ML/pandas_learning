# %%
people = {
    "first" : ["Corey","Jane","John"],
    "last"  : ["Schafer","Doe","Doe"],
    "email" : ["Corey@gmail.com","Jane@gmail.com","John@yahoo.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   John@yahoo.com

# %%
filt = (df["last"] == "Schafer") | (df["first"] == "John")

# %%
df.loc[filt,"email"] # ~ for opposite result
# Out:
# 0    Corey@gmail.com
# 2     John@yahoo.com
# Name: email, dtype: object

# %%
# The stack overflow example

# %%
df = pd.read_csv("data/survey_results_public.csv")
schema_df = pd.read_csv("data/survey_results_schema.csv")

# %%
pd.set_option("display.max_columns",df.shape[1])
pd.set_option("display.max_rows",df.shape[0])

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  \
# 0                                                NaN
# 1  Technical documentation;Blogs;Books;Written Tu...
# 2  Technical documentation;Blogs;Books;Written Tu...
# 3  Stack Overflow;How-to videos;Interactive tutorial
# 4  Technical documentation;Blogs;Written Tutorial...
#
#                                              TechDoc YearsCode YearsCodePro  \
# 0                                                NaN       NaN          NaN
# 1  API document(s) and/or SDK document(s);User gu...        20           17
# 2  API document(s) and/or SDK document(s);User gu...        37           27
# 3                                                NaN         4          NaN
# 4  API document(s) and/or SDK document(s);User gu...         9          NaN
#
#                  DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy  \
# 0                    NaN     NaN               NaN        NaN        NaN
# 1  Developer, full-stack     NaN               NaN        NaN        NaN
# 2   Developer Experience     NaN               NaN        NaN        NaN
# 3  Developer, full-stack     NaN               NaN        NaN        NaN
# 4  Developer, full-stack     NaN               NaN        NaN        NaN
#
#   TechEndorse                                            Country Currency  \
# 0         NaN                           United States of America      NaN
# 1         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 2         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 3         NaN                                             Canada      NaN
# 4         NaN                                             Norway      NaN
#
#    CompTotal                             LanguageHaveWorkedWith  \
# 0        NaN                                                NaN
# 1        NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2        NaN                                                 C#
# 3        NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4        NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                               LanguageWantToWorkWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#                                      LanguageAdmired  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#             DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                              NaN                         NaN
# 1      Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2       Firebase Realtime Database  Firebase Realtime Database
# 3  MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 4                PostgreSQL;SQLite           PostgreSQL;SQLite
#
#               DatabaseAdmired                    PlatformHaveWorkedWith  \
# 0                         NaN                                       NaN
# 1                  PostgreSQL  Amazon Web Services (AWS);Heroku;Netlify
# 2  Firebase Realtime Database                              Google Cloud
# 3    MongoDB;MySQL;PostgreSQL   Amazon Web Services (AWS);Fly.io;Heroku
# 4           PostgreSQL;SQLite                                       NaN
#
#                      PlatformWantToWorkWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3          Amazon Web Services (AWS);Vercel
# 4                                       NaN
#
#                             PlatformAdmired  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3                 Amazon Web Services (AWS)
# 4                                       NaN
#
#                    WebframeHaveWorkedWith            WebframeWantToWorkWith  \
# 0                                     NaN                               NaN
# 1           Express;Next.js;Node.js;React  Express;Htmx;Node.js;React;Remix
# 2                            ASP.NET CORE                      ASP.NET CORE
# 3  jQuery;Next.js;Node.js;React;WordPress      jQuery;Next.js;Node.js;React
# 4                                     NaN                               NaN
#
#                 WebframeAdmired   EmbeddedHaveWorkedWith  \
# 0                           NaN                      NaN
# 1         Express;Node.js;React                      NaN
# 2                  ASP.NET CORE              Rasberry Pi
# 3  jQuery;Next.js;Node.js;React              Rasberry Pi
# 4                           NaN  CMake;Cargo;Rasberry Pi
#
#   EmbeddedWantToWorkWith    EmbeddedAdmired  \
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2            Rasberry Pi        Rasberry Pi
# 3                    NaN                NaN
# 4      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                             MiscTechHaveWorkedWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                     NumPy;Pandas;Ruff;TensorFlow
# 4                                              NaN
#
#                             MiscTechWantToWorkWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                                    MiscTechAdmired  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                               Docker;npm;Pip
# 4                                 APT;Make;npm
#
#                        ToolsTechWantToWorkWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                        Docker;Kubernetes;npm
# 4                                     APT;Make
#
#                               ToolsTechAdmired  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                                   Docker;npm
# 4                                     APT;Make
#
#           NEWCollabToolsHaveWorkedWith         NEWCollabToolsWantToWorkWith  \
# 0                                  NaN                                  NaN
# 1  PyCharm;Visual Studio Code;WebStorm  PyCharm;Visual Studio Code;WebStorm
# 2                        Visual Studio                        Visual Studio
# 3                                  NaN                                  NaN
# 4                                  Vim                                  Vim
#
#                  NEWCollabToolsAdmired        OpSysPersonal use  \
# 0                                  NaN                      NaN
# 1  PyCharm;Visual Studio Code;WebStorm            MacOS;Windows
# 2                        Visual Studio                  Windows
# 3                                  NaN                      NaN
# 4                                  Vim  Other (please specify):
#
#   OpSysProfessional use                     OfficeStackAsyncHaveWorkedWith  \
# 0                   NaN                                                NaN
# 1                 MacOS                                                NaN
# 2               Windows                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN  GitHub Discussions;Markdown File;Obsidian;Stac...
#
#               OfficeStackAsyncWantToWorkWith  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                      OfficeStackAsyncAdmired  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 0                                           NaN                           NaN
# 1                         Microsoft Teams;Slack                         Slack
# 2  Google Chat;Google Meet;Microsoft Teams;Zoom  Google Chat;Google Meet;Zoom
# 3                                           NaN                           NaN
# 4                              Discord;Whatsapp              Discord;Whatsapp
#
#          OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# 0                           NaN                       NaN
# 1                         Slack                       NaN
# 2  Google Chat;Google Meet;Zoom                       NaN
# 3                           NaN                       NaN
# 4              Discord;Whatsapp                       NaN
#
#   AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
#
#                                           NEWSOSites             SOVisitFreq  \
# 0  I have never visited Stack Overflow or the Sta...                     NaN
# 1  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
# 2  Stack Overflow;Stack Exchange;Stack Overflow B...  Multiple times per day
# 3                                     Stack Overflow   Daily or almost daily
# 4  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
#
#   SOAccount              SOPartFreq  \
# 0       NaN                     NaN
# 1       Yes  Multiple times per day
# 2       Yes  Multiple times per day
# 3        No                     NaN
# 4       Yes  Multiple times per day
#
#                                                SOHow           SOComm  \
# 0                                                NaN              NaN
# 1  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 3                     Quickly finding code solutions   No, not really
# 4  Quickly finding code solutions;Engage with com...  Yes, definitely
#
#                   AISelect          AISent  \
# 0                      Yes  Very favorable
# 1  No, and I don't plan to             NaN
# 2  No, and I don't plan to             NaN
# 3                      Yes  Very favorable
# 4  No, and I don't plan to             NaN
#
#                                                AIBen           AIAcc  \
# 0                              Increase productivity             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Increase productivity;Greater efficiency;Impro...  Somewhat trust
# 4                                                NaN             NaN
#
#                        AIComplex  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  Bad at handling complex tasks
# 4                            NaN
#
#                                AIToolCurrently Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Learning about a codebase;Project planning;Wri...
# 4                                                NaN
#
#                            AIToolInterested in Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Testing code;Committing and reviewing code;Pre...
# 4                                                NaN
#
#   AIToolNot interested in Using  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                           AINextMuch more integrated AINextNo change  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Learning about a codebase;Project planning;Wri...             NaN
# 4                                                NaN             NaN
#
#   AINextMore integrated AINextLess integrated AINextMuch less integrated  \
# 0                   NaN                   NaN                        NaN
# 1                   NaN                   NaN                        NaN
# 2                   NaN                   NaN                        NaN
# 3                   NaN                   NaN                        NaN
# 4                   NaN                   NaN                        NaN
#
#   AIThreat                                           AIEthics  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                                NaN
# 3       No  Circulating misinformation or disinformation;M...
# 4      NaN                                                NaN
#
#                         AIChallenges TBranch                  ICorPM  WorkExp  \
# 0                                NaN      No                     NaN      NaN
# 1                                NaN     Yes  Individual contributor     17.0
# 2                                NaN      No                     NaN      NaN
# 3  Don’t trust the output or answers     NaN                     NaN      NaN
# 4                                NaN     NaN                     NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5  \
# 0         NaN         NaN         NaN         NaN         NaN
# 1       Agree    Disagree       Agree       Agree       Agree
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
#                   Knowledge_6 Knowledge_7 Knowledge_8 Knowledge_9 Frequency_1  \
# 0                         NaN         NaN         NaN         NaN         NaN
# 1  Neither agree nor disagree    Disagree       Agree       Agree         NaN
# 2                         NaN         NaN         NaN         NaN         NaN
# 3                         NaN         NaN         NaN         NaN         NaN
# 4                         NaN         NaN         NaN         NaN         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering Frustration  \
# 0         NaN         NaN           NaN           NaN         NaN
# 1         NaN         NaN           NaN           NaN         NaN
# 2         NaN         NaN           NaN           NaN         NaN
# 3         NaN         NaN           NaN           NaN         NaN
# 4         NaN         NaN           NaN           NaN         NaN
#
#   ProfessionalTech ProfessionalCloud ProfessionalQuestion Industry  \
# 0              NaN               NaN                  NaN      NaN
# 1              NaN               NaN                  NaN      NaN
# 2              NaN               NaN                  NaN      NaN
# 3              NaN               NaN                  NaN      NaN
# 4              NaN               NaN                  NaN      NaN
#
#    JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# 0             NaN             NaN             NaN             NaN
# 1             0.0             0.0             0.0             0.0
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# 0             NaN             NaN             NaN              NaN
# 1             0.0             0.0             0.0              0.0
# 2             NaN             NaN             NaN              NaN
# 3             NaN             NaN             NaN              NaN
# 4             NaN             NaN             NaN              NaN
#
#    JobSatPoints_11           SurveyLength SurveyEase  ConvertedCompYearly  \
# 0              NaN                    NaN        NaN                  NaN
# 1              0.0                    NaN        NaN                  NaN
# 2              NaN  Appropriate in length       Easy                  NaN
# 3              NaN               Too long       Easy                  NaN
# 4              NaN              Too short       Easy                  NaN
#
#    JobSat
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
filt = df["LanguageHaveWorkedWith"].str.contains("Python", na= False)

# %%
df.loc[filt,"LanguageHaveWorkedWith"]
# Out:
# 0                                                      NaN
# 5        Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 6                                                        R
# 10                                  JavaScript;Python;Ruby
# 12       Bash/Shell (all shells);C#;JavaScript;PowerShe...
# 17                          HTML/CSS;JavaScript;TypeScript
# 18                   C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 20       Bash/Shell (all shells);HTML/CSS;PHP;Python;SQ...
# 21                                C#;HTML/CSS;Java;PHP;SQL
# 23                      HTML/CSS;JavaScript;PHP;Python;SQL
# 25       C#;HTML/CSS;Java;JavaScript;Python;SQL;VBA;Vis...
# 31       Bash/Shell (all shells);Go;HTML/CSS;Python;Sca...
# 34       C++;HTML/CSS;Java;JavaScript;MATLAB;Perl;Power...
# 35       Bash/Shell (all shells);C#;C++;HTML/CSS;PowerS...
# 46                                                   C;C++
# 47                                    Crystal;Julia;R;Ruby
# 48                                      Delphi;Fortran;SQL
# 49                                     Java;JavaScript;SQL
# 51       Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScr...
# 52       C;HTML/CSS;Java;JavaScript;PowerShell;SQL;Type...
# 55                                         C;Go;Python;SQL
# 58                    C;C++;HTML/CSS;JavaScript;Python;SQL
# 72       Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 75                                     HTML/CSS;JavaScript
# 76                  Groovy;HTML/CSS;Java;JavaScript;Python
# 78       Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 79                                C#;JavaScript;TypeScript
# 80                                      C#;PowerShell;Rust
# 84       C#;C++;HTML/CSS;JavaScript;Kotlin;Lua;PowerShe...
# 85                                                     SQL
# 87                                    HTML/CSS;Python;Rust
# 89       C;C++;HTML/CSS;Java;JavaScript;PHP;SQL;Visual ...
# 92       C;C++;Groovy;HTML/CSS;Java;JavaScript;PHP;Pyth...
# 96                   Bash/Shell (all shells);C#;JavaScript
# 97               Bash/Shell (all shells);C;C++;Java;Python
# 104      C#;HTML/CSS;Java;JavaScript;PHP;SQL;VBA;Visual...
# 105             Bash/Shell (all shells);Go;HTML/CSS;Python
# 107                                        C#;HTML/CSS;VBA
# 113      C;C#;C++;Elixir;Erlang;Go;HTML/CSS;Java;JavaSc...
# 115                                                     C#
# 116      Bash/Shell (all shells);C;C++;Kotlin;PowerShel...
# 122      Java;JavaScript;Kotlin;Lua;MicroPython;Python;...
# 123                                                     Go
# 126                                              Go;Python
# 127      Assembly;Bash/Shell (all shells);C;C#;C++;Dart...
# 128              C#;C++;HTML/CSS;JavaScript;PowerShell;SQL
# 131                                  JavaScript;TypeScript
# 136      Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 139      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 140      Bash/Shell (all shells);Dart;JavaScript;Python...
# 142                                             C;C++;Java
# 144      C#;HTML/CSS;JavaScript;SQL;TypeScript;Visual B...
# 145              Bash/Shell (all shells);Dart;Python;Swift
# 147               Go;Java;JavaScript;Kotlin;PHP;Python;SQL
# 148                  C#;HTML/CSS;JavaScript;SQL;TypeScript
# 152                                 C#;HTML/CSS;Python;SQL
# 157                             C#;HTML/CSS;JavaScript;SQL
# 159                C;C#;C++;HTML/CSS;JavaScript;TypeScript
# 164                                                   Java
# 165                  C#;HTML/CSS;JavaScript;SQL;TypeScript
# 171      Bash/Shell (all shells);C#;Go;PowerShell;Pytho...
# 175              C#;Go;Groovy;HTML/CSS;Java;JavaScript;SQL
# 176                           C#;JavaScript;SQL;TypeScript
# 178      Bash/Shell (all shells);C#;Clojure;Lisp;Lua;Pr...
# 182      C#;HTML/CSS;JavaScript;SQL;TypeScript;Visual B...
# 187      Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java...
# 195           Dart;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 196      Bash/Shell (all shells);C;C++;HTML/CSS;Java;Ja...
# 199                           HTML/CSS;Java;JavaScript;SQL
# 201              C++;Java;JavaScript;Python;TypeScript;VBA
# 202                           HTML/CSS;Java;JavaScript;PHP
# 203      Assembly;Bash/Shell (all shells);C;Haskell;HTM...
# 204      C#;HTML/CSS;JavaScript;Lua;PowerShell;SQL;Type...
# 205                                              R;SQL;VBA
# 209      Bash/Shell (all shells);C;C#;Go;HTML/CSS;JavaS...
# 215         C#;C++;F#;JavaScript;PowerShell;SQL;TypeScript
# 219      C;C++;HTML/CSS;Java;JavaScript;Python;SQL;Type...
# 220                           C;C++;Java;Kotlin;MATLAB;SQL
# 225      Bash/Shell (all shells);Go;HTML/CSS;Rust;TypeS...
# 226                                            C#;HTML/CSS
# 227      Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
# 229                HTML/CSS;JavaScript;Ruby;SQL;TypeScript
# 231                                               Python;R
# 234      Bash/Shell (all shells);C;C++;Dart;Go;HTML/CSS...
# 241                                     JavaScript;PHP;SQL
# 243                                    Java;JavaScript;SQL
# 245                                                C#;Ruby
# 248                          C#;Java;JavaScript;Python;SQL
# 250      C++;Go;Java;JavaScript;Kotlin;Objective-C;Pyth...
# 251      Bash/Shell (all shells);C;C++;MATLAB;Python;Ru...
# 263                           HTML/CSS;JavaScript;Ruby;SQL
# 264      Bash/Shell (all shells);Elixir;Go;Groovy;HTML/...
# 265                                            C;C#;Python
# 268                    HTML/CSS;JavaScript;Lisp;Python;SQL
# 271                   Groovy;Java;JavaScript;MATLAB;Python
# 273                  C#;C++;Java;Lua;PowerShell;Python;SQL
# 278             HTML/CSS;Java;JavaScript;Kotlin;TypeScript
# 279      Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 282      Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 285                                          Go;JavaScript
# 286                          Groovy;Java;Kotlin;PowerShell
# 289      Bash/Shell (all shells);C#;Java;JavaScript;Pyt...
# 292                                Bash/Shell (all shells)
# 293                                             JavaScript
# 295               C;HTML/CSS;Java;JavaScript;MATLAB;Python
# 306      Bash/Shell (all shells);Haskell;Java;Python;R;SQL
# 307                         Bash/Shell (all shells);Python
# 308         Bash/Shell (all shells);Objective-C;Perl;Swift
# 309      Bash/Shell (all shells);C;C++;Java;Objective-C...
# 312      Bash/Shell (all shells);C++;JavaScript;Python;SQL
# 314      Bash/Shell (all shells);HTML/CSS;JavaScript;SQ...
# 315                                                  C;C++
# 322                     HTML/CSS;JavaScript;SQL;TypeScript
# 325                         Elixir;HTML/CSS;JavaScript;PHP
# 327             Bash/Shell (all shells);C#;Java;Python;SQL
# 330      Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 332                                       C#;Delphi;Go;SQL
# 334        Bash/Shell (all shells);C;C++;Go;Lua;Python;SQL
# 338                  HTML/CSS;JavaScript;Python;TypeScript
# 340          HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript
# 341      Bash/Shell (all shells);C;C++;Go;Groovy;HTML/C...
# 343                                                SQL;VBA
# 344                               C#;Java;Python;Scala;SQL
# 345                               Java;Lua;Python;Rust;SQL
# 348                          C;C++;Dart;Go;Haskell;Lua;Zig
# 350      Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 351                         JavaScript;Solidity;TypeScript
# 355                      C#;HTML/CSS;JavaScript;Lua;Python
# 356      C;C#;C++;Dart;HTML/CSS;JavaScript;Lua;MATLAB;P...
# 359      Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java...
# 361            C++;Java;MicroPython;Python;Rust;TypeScript
# 362      Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 365      C;C#;C++;Dart;Fortran;Go;HTML/CSS;Java;JavaScr...
# 367                            HTML/CSS;JavaScript;PHP;SQL
# 375                  C;C++;HTML/CSS;Java;JavaScript;Python
# 380                               HTML/CSS;JavaScript;Ruby
# 382                                 Groovy;Java;Kotlin;SQL
# 384      C#;Go;HTML/CSS;JavaScript;PowerShell;Python;SQ...
# 389              HTML/CSS;JavaScript;Python;SQL;TypeScript
# 390                    HTML/CSS;JavaScript;Ruby;TypeScript
# 391          Bash/Shell (all shells);Groovy;PowerShell;SQL
# 394                                  JavaScript;TypeScript
# 397                    C;Java;JavaScript;PowerShell;Python
# 398      Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 407      Bash/Shell (all shells);C++;Go;HTML/CSS;Java;J...
# 410      Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java...
# 412      Bash/Shell (all shells);C;GDScript;Go;HTML/CSS...
# 417                                               C++;Rust
# 422                                 Dart;Java;Kotlin;Swift
# 424                                                 Delphi
# 428                 Bash/Shell (all shells);Go;Python;Rust
# 430                                HTML/CSS;JavaScript;PHP
# 431      Bash/Shell (all shells);C#;C++;Go;HTML/CSS;Jav...
# 432               C#;Go;HTML/CSS;JavaScript;SQL;TypeScript
# 433                                 C#;HTML/CSS;JavaScript
# 435                                                 C;Rust
# 438         C++;HTML/CSS;JavaScript;Lisp;PowerShell;Python
# 439                             HTML/CSS;JavaScript;Python
# 440                                 C#;HTML/CSS;JavaScript
# 442                     C#;HTML/CSS;Java;JavaScript;Python
# 446      Go;Groovy;HTML/CSS;JavaScript;Python;SQL;TypeS...
# 447                          Apex;C#;JavaScript;Python;SQL
# 456                       Bash/Shell (all shells);C;C++;Go
# 462                    C;JavaScript;MicroPython;Python;SQL
# 464                                               C;Python
# 468      Fortran;HTML/CSS;JavaScript;Python;SQL;TypeScript
# 469                       Bash/Shell (all shells);Java;SQL
# 470       Bash/Shell (all shells);HTML/CSS;Java;TypeScript
# 477                                         C;C++;Perl;SQL
# 482      Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
# 485      Bash/Shell (all shells);Java;JavaScript;TypeSc...
# 486                                        HTML/CSS;Python
# 489      Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 494      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 495                                            Java;Kotlin
# 496      Assembly;Bash/Shell (all shells);C;C++;Go;HTML...
# 498                             C#;HTML/CSS;JavaScript;SQL
# 499         C#;GDScript;HTML/CSS;JavaScript;Lua;PowerShell
# 505      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 510      Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 514      Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 515      Ada;Apex;Assembly;Bash/Shell (all shells);C++;...
# 517                                                     C#
# 518                                        MATLAB;Python;R
# 522           Go;JavaScript;PHP;PowerShell;Python;Ruby;SQL
# 528                  C#;HTML/CSS;JavaScript;PowerShell;SQL
# 529                  C#;HTML/CSS;PowerShell;SQL;TypeScript
# 530      C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;...
# 532              C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 533       HTML/CSS;JavaScript;Kotlin;Python;SQL;TypeScript
# 536      Bash/Shell (all shells);C++;HTML/CSS;JavaScrip...
# 537      Assembly;Bash/Shell (all shells);C;C++;Go;HTML...
# 538                         Bash/Shell (all shells);Python
# 539      Bash/Shell (all shells);C;JavaScript;Lua;Perl;...
# 543                     Bash/Shell (all shells);C++;Python
# 544      Bash/Shell (all shells);C;C#;Clojure;GDScript;...
# 545               Go;JavaScript;Python;Rust;SQL;TypeScript
# 546                 Bash/Shell (all shells);Fortran;Python
# 547      Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 548         HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 549      Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 554                         C;C++;JavaScript;Python;Zephyr
# 555             C++;Lua;MicroPython;Python;Rust;TypeScript
# 560                                             C#;C++;SQL
# 563      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 565      C#;HTML/CSS;PowerShell;Python;SQL;VBA;Visual B...
# 566                  C#;HTML/CSS;JavaScript;SQL;TypeScript
# 568      Bash/Shell (all shells);Go;Java;JavaScript;Lis...
# 570      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 572                C#;JavaScript;PowerShell;SQL;TypeScript
# 573      Bash/Shell (all shells);Go;HTML/CSS;PowerShell...
# 575      Bash/Shell (all shells);C#;Go;Java;JavaScript;...
# 576        Bash/Shell (all shells);HTML/CSS;JavaScript;PHP
# 579      Bash/Shell (all shells);C;HTML/CSS;Java;JavaSc...
# 582                      Bash/Shell (all shells);PHP;R;SQL
# 585                                                  R;SQL
# 587      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 588      Bash/Shell (all shells);HTML/CSS;JavaScript;Mi...
# 589      Bash/Shell (all shells);C#;Clojure;Elixir;Erla...
# 590                      C#;Java;JavaScript;SQL;TypeScript
# 591      Bash/Shell (all shells);C;C++;Go;HTML/CSS;Java...
# 592                  C#;HTML/CSS;JavaScript;SQL;TypeScript
# 593                                               Python;R
# 594               C#;JavaScript;Python;Ruby;SQL;TypeScript
# 597                     Bash/Shell (all shells);C++;Python
# 599      Bash/Shell (all shells);C#;Groovy;HTML/CSS;Jav...
# 606                                Go;Python;Ruby;Rust;SQL
# 608      Assembly;Bash/Shell (all shells);C#;GDScript;H...
# 613      C;C#;C++;HTML/CSS;Java;JavaScript;MicroPython;...
# 614                                         Assembly;C;C++
# 620       Bash/Shell (all shells);Go;JavaScript;Python;SQL
# 621              Bash/Shell (all shells);C;C++;Lisp;Python
# 622                          C#;HTML/CSS;JavaScript;Python
# 624                                        Apex;Python;SQL
# 625                      Dart;Haskell;Java;Kotlin;Python;R
# 630      Assembly;Bash/Shell (all shells);C;C++;Java;Ja...
# 633                         C++;HTML/CSS;JavaScript;Python
# 634      Bash/Shell (all shells);C;C++;Go;Java;Python;R...
# 635                        HTML/CSS;Java;JavaScript;Python
# 636      C;C#;C++;JavaScript;Objective-C;PowerShell;Pyt...
# 637      Bash/Shell (all shells);C;C++;HTML/CSS;Java;Ja...
# 638      Bash/Shell (all shells);C;C#;C++;Dart;HTML/CSS...
# 641       C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript
# 642                                                 F#;SQL
# 644                           C#;JavaScript;SQL;TypeScript
# 652      Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 657      Groovy;HTML/CSS;Java;JavaScript;PHP;Python;SQL...
# 659      Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 665                   JavaScript;PHP;Python;SQL;TypeScript
# 666                                                    NaN
# 667      Groovy;HTML/CSS;Java;JavaScript;Kotlin;PowerSh...
# 669            Dart;Go;HTML/CSS;JavaScript;Python;Rust;SQL
# 670         C++;HTML/CSS;Java;JavaScript;MATLAB;Python;SQL
# 671           C#;HTML/CSS;JavaScript;PowerShell;TypeScript
# 673      Bash/Shell (all shells);C#;Go;HTML/CSS;Java;Ja...
# 674         Bash/Shell (all shells);C#;JavaScript;Rust;SQL
# 675      Bash/Shell (all shells);C#;Go;HTML/CSS;Java;Ja...
# 676                  Go;HTML/CSS;JavaScript;SQL;TypeScript
# 681      Bash/Shell (all shells);C#;HTML/CSS;PowerShell...
# 683                                                 Python
# 685                             Java;JavaScript;TypeScript
# 686             Dart;Go;HTML/CSS;JavaScript;SQL;TypeScript
# 690                           Bash/Shell (all shells);Java
# 692      Bash/Shell (all shells);C#;C++;Groovy;HTML/CSS...
# 695                                      Apex;C;Cobol;Ruby
# 697      Bash/Shell (all shells);C++;Dart;Go;JavaScript...
# 699                       Bash/Shell (all shells);Ruby;SQL
# 702                      Bash/Shell (all shells);Go;Python
# 703      Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 705                    Bash/Shell (all shells);C;C#;Python
# 708                         Groovy;HTML/CSS;Lua;Python;SQL
# 713      Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
# 714                C#;JavaScript;PowerShell;SQL;TypeScript
# 722      Bash/Shell (all shells);Dart;Go;HTML/CSS;JavaS...
# 723                                        Java;Kotlin;PHP
# 729      C++;HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL
# 730      Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
# 731      Bash/Shell (all shells);C;C#;C++;Delphi;Lua;Ob...
# 736                                               Java;SQL
# 738                                     PHP;PowerShell;SQL
# 739                                               Dart;Zig
# 740                                    Apex;C#;Go;Rust;SQL
# 745                     HTML/CSS;JavaScript;Python;SQL;VBA
# 751      Bash/Shell (all shells);C;C++;Go;HTML/CSS;Java...
# 753      Bash/Shell (all shells);C#;C++;HTML/CSS;JavaSc...
# 754      Assembly;C;C++;HTML/CSS;JavaScript;Python;R;Ty...
# 757       Bash/Shell (all shells);C#;C++;F#;Go;Python;Rust
# 758               Assembly;Bash/Shell (all shells);C;C++;R
# 760                                                 C#;SQL
# 761      C#;Go;HTML/CSS;Java;JavaScript;PowerShell;Pyth...
# 762      Bash/Shell (all shells);C#;C++;HTML/CSS;Java;J...
# 764                   Bash/Shell (all shells);C;C++;Python
# 768                                                C#;Java
# 773      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 775      Bash/Shell (all shells);C;C++;Java;JavaScript;...
# 777      Assembly;C;C#;C++;Java;JavaScript;Perl;PHP;Pyt...
# 781      Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 782      Assembly;C++;Go;Java;Objective-C;PHP;Python;Swift
# 783      Bash/Shell (all shells);C++;HTML/CSS;Java;Java...
# 788                     Bash/Shell (all shells);C++;Python
# 792                                           C;C++;Python
# 797                                  Java;Kotlin;PHP;Swift
# 804      C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Objec...
# 805      Assembly;Bash/Shell (all shells);C;C++;Cobol;G...
# 807      Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 810                                  C#;Fortran;Python;SQL
# 811      Bash/Shell (all shells);C;C++;Go;HTML/CSS;Java...
# 812                                            Go;Java;SQL
# 814                            C;JavaScript;Lua;Python;SQL
# 816                             HTML/CSS;Python;TypeScript
# 823      Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 824      C#;HTML/CSS;JavaScript;Kotlin;Objective-C;Swif...
# 825                      HTML/CSS;Java;JavaScript;Ruby;SQL
# 828                       Cobol;Java;JavaScript;Python;SQL
# 829      Bash/Shell (all shells);C;Go;Groovy;HTML/CSS;J...
# 830                                      JavaScript;Python
# 831      Bash/Shell (all shells);HTML/CSS;JavaScript;SQ...
# 834                               C#;JavaScript;TypeScript
# 838                                  JavaScript;Python;SQL
# 839                                HTML/CSS;JavaScript;PHP
# 840                  JavaScript;Python;Ruby;SQL;TypeScript
# 841                                      Assembly;C;Python
# 843      Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 844      Bash/Shell (all shells);JavaScript;Lisp;Python...
# 850                                             C;HTML/CSS
# 852                             JavaScript;Rust;TypeScript
# 853      Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java...
# 854      Bash/Shell (all shells);C#;Groovy;HTML/CSS;Jav...
# 855                     Bash/Shell (all shells);Python;SQL
# 857                         Bash/Shell (all shells);Go;Lua
# 861      Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 862                                               Java;SQL
# 865           C#;HTML/CSS;JavaScript;PowerShell;Python;SQL
# 868                            C;MATLAB;MicroPython;Python
# 869        Bash/Shell (all shells);HTML/CSS;PHP;Python;SQL
# 871                                          C#;C++;Python
# 873                       Bash/Shell (all shells);Java;SQL
# 880      C#;HTML/CSS;Java;JavaScript;PowerShell;Python;...
# 881                         HTML/CSS;JavaScript;PowerShell
# 884      Bash/Shell (all shells);C++;Go;Java;JavaScript...
# 885         C#;GDScript;HTML/CSS;JavaScript;SQL;TypeScript
# 886      HTML/CSS;JavaScript;PowerShell;Python;SQL;Swif...
# 887                                       C;JavaScript;PHP
# 892                       Bash/Shell (all shells);C;Python
# 894      Bash/Shell (all shells);C;Fortran;HTML/CSS;Jav...
# 895      Assembly;Bash/Shell (all shells);C;C#;C++;Cloj...
# 897                                                 Python
# 901      Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 902      C;C#;Dart;JavaScript;PowerShell;Python;SQL;Typ...
# 909                                  JavaScript;TypeScript
# 910                         HTML/CSS;JavaScript;TypeScript
# 913                    Assembly;C#;Go;PowerShell;Ruby;Rust
# 914      Assembly;Bash/Shell (all shells);C;HTML/CSS;Pe...
# 917       C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript
# 918                                                    PHP
# 920                                             C++;Python
# 923                         C;C#;HTML/CSS;Java;Python;Rust
# 924                                            Java;Python
# 925      Bash/Shell (all shells);C++;HTML/CSS;Java;Java...
# 929                 JavaScript;PowerShell;Python;SQL;Swift
# 930      Bash/Shell (all shells);C;Go;Java;PowerShell;P...
# 931                                                 Python
# 932         Bash/Shell (all shells);C;Haskell;HTML/CSS;Lua
# 933                                                SQL;VBA
# 936                                                    NaN
# 937                         Groovy;JavaScript;Python;R;SQL
# 940      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 941      Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 942      Bash/Shell (all shells);HTML/CSS;JavaScript;Ko...
# 947                                  JavaScript;TypeScript
# 948      Bash/Shell (all shells);C;C++;HTML/CSS;Java;Ru...
# 951                                          C;Python;Rust
# 955                                   Go;HTML/CSS;Ruby;SQL
# 967                   C;Go;Java;JavaScript;Python;Rust;SQL
# 970      C++;HTML/CSS;JavaScript;Lua;PHP;Rust;SQL;TypeS...
# 971                                                   Rust
# 975      HTML/CSS;Java;JavaScript;PHP;PowerShell;Python...
# 976         Bash/Shell (all shells);C;C#;Java;Perl;PHP;SQL
# 977                      C#;HTML/CSS;JavaScript;TypeScript
# 981                                           Apex;C#;Ruby
# 982                           C#;JavaScript;SQL;TypeScript
# 983      C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;PHP;P...
# 986      Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 987      Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 988                  HTML/CSS;JavaScript;Python;TypeScript
# 990      Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 993                C#;JavaScript;PowerShell;SQL;TypeScript
# 996      Bash/Shell (all shells);C;Go;HTML/CSS;Objectiv...
# 999      Bash/Shell (all shells);C;Haskell;HTML/CSS;Jav...
# 1002     Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 1005     Bash/Shell (all shells);C;C++;Go;Java;JavaScri...
# 1009                                        C#;Go;Java;SQL
# 1012                                          Python;R;SQL
# 1015                                       C#;HTML/CSS;SQL
# 1016     HTML/CSS;Java;JavaScript;Perl;PHP;R;SQL;TypeSc...
# 1017                   Bash/Shell (all shells);Go;Lua;Rust
# 1019     Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 1023      Bash/Shell (all shells);C;Lisp;MATLAB;Python;SQL
# 1024     Assembly;Bash/Shell (all shells);C#;Go;JavaScr...
# 1025     Bash/Shell (all shells);C#;Dart;HTML/CSS;JavaS...
# 1030     C;Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeS...
# 1031     Bash/Shell (all shells);C#;C++;Groovy;HTML/CSS...
# 1034                                 JavaScript;Python;SQL
# 1042                  Bash/Shell (all shells);C;C++;Python
# 1043         HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript
# 1045     C;C++;HTML/CSS;Java;JavaScript;PowerShell;Pyth...
# 1046                                           Java;Python
# 1049                               HTML/CSS;JavaScript;PHP
# 1050                 Bash/Shell (all shells);Go;Python;SQL
# 1051           C;C#;C++;Go;HTML/CSS;Java;JavaScript;Python
# 1053                       Go;HTML/CSS;JavaScript;Ruby;SQL
# 1054                   Go;JavaScript;Python;SQL;TypeScript
# 1060     Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 1061     Bash/Shell (all shells);Go;Java;JavaScript;Kot...
# 1066     Bash/Shell (all shells);Java;JavaScript;SQL;Ty...
# 1067     Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 1068                                               SQL;VBA
# 1070     Bash/Shell (all shells);Go;Java;JavaScript;Kot...
# 1072                             JavaScript;PHP;TypeScript
# 1074     Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScr...
# 1076                      HTML/CSS;Lua;MATLAB;Python;R;SQL
# 1081     C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;T...
# 1085                                            Python;SQL
# 1089                 C#;HTML/CSS;JavaScript;SQL;TypeScript
# 1093     Bash/Shell (all shells);HTML/CSS;JavaScript;Lu...
# 1094                                  Dart;Java;Python;SQL
# 1096                                 JavaScript;Python;SQL
# 1102     Ada;Bash/Shell (all shells);C;C++;HTML/CSS;Jav...
# 1104     Bash/Shell (all shells);C;Go;HTML/CSS;Java;Python
# 1105            Bash/Shell (all shells);C++;Fortran;Python
# 1111     Bash/Shell (all shells);HTML/CSS;PHP;SQL;TypeS...
# 1113                                            C#;C++;SQL
# 1117        Bash/Shell (all shells);C#;HTML/CSS;JavaScript
# 1125                HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 1126                            C#;HTML/CSS;JavaScript;PHP
# 1128     HTML/CSS;JavaScript;PowerShell;Ruby;SQL;TypeSc...
# 1131     Assembly;Bash/Shell (all shells);C;C#;C++;Go;H...
# 1132                                   HTML/CSS;JavaScript
# 1134     C;C#;C++;Dart;HTML/CSS;JavaScript;Kotlin;Power...
# 1135         Go;HTML/CSS;JavaScript;Python;Rust;TypeScript
# 1136          C++;Java;JavaScript;Kotlin;Python;TypeScript
# 1137                        Bash/Shell (all shells);Python
# 1138                          JavaScript;Python;TypeScript
# 1141     Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 1143                  Bash/Shell (all shells);Python;R;SQL
# 1144     GDScript;Go;HTML/CSS;JavaScript;Lua;MicroPytho...
# 1149                                     C#;JavaScript;SQL
# 1151     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1153     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1157               HTML/CSS;Java;JavaScript;MATLAB;PHP;SQL
# 1164                                              C;Python
# 1165                           HTML/CSS;JavaScript;PHP;SQL
# 1169     Bash/Shell (all shells);C;C#;C++;Dart;Java;Jav...
# 1172     Bash/Shell (all shells);C;C#;C++;GDScript;HTML...
# 1174     Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScr...
# 1175     Bash/Shell (all shells);C;C++;HTML/CSS;Java;Ja...
# 1176                           HTML/CSS;JavaScript;PHP;SQL
# 1177     Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1178     Assembly;Bash/Shell (all shells);C;C#;C++;HTML...
# 1179               C;C#;C++;Dart;Go;JavaScript;Python;Rust
# 1180     Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 1181     Bash/Shell (all shells);C;Clojure;Go;HTML/CSS;...
# 1182               C;C++;JavaScript;Objective-C;Python;SQL
# 1184     Bash/Shell (all shells);C#;Go;HTML/CSS;JavaScr...
# 1185                          C#;JavaScript;SQL;TypeScript
# 1187                                     C#;C++;Lua;Python
# 1189     Bash/Shell (all shells);HTML/CSS;JavaScript;Ty...
# 1192                 C#;SQL;TypeScript;Visual Basic (.Net)
# 1193                      C++;JavaScript;Python;TypeScript
# 1194             Bash/Shell (all shells);JavaScript;Python
# 1196                                               SQL;VBA
# 1198     C;C#;C++;GDScript;HTML/CSS;Java;JavaScript;Pow...
# 1199                   Bash/Shell (all shells);Go;HTML/CSS
# 1202                                                    C#
# 1203                                                 Swift
# 1205                        HTML/CSS;JavaScript;TypeScript
# 1206     C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;PowerS...
# 1207                                                Python
# 1208                                                   C++
# 1209                             Go;Python;Rust;TypeScript
# 1215                                     C#;SQL;TypeScript
# 1216                                          C;C++;Python
# 1218                          Go;JavaScript;PHP;TypeScript
# 1219     Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 1221      C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript
# 1222     Bash/Shell (all shells);C++;Java;JavaScript;Ko...
# 1224                       Dart;GDScript;Kotlin;TypeScript
# 1228               C;C++;Go;Lua;PowerShell;Python;Ruby;SQL
# 1232     Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 1234     C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;T...
# 1235                            C#;SQL;Visual Basic (.Net)
# 1236     Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 1241                                       HTML/CSS;Python
# 1249     Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 1256                                                C#;SQL
# 1257                   Elixir;Erlang;Go;Kotlin;PHP;SQL;Zig
# 1259                                  C#;Python;TypeScript
# 1261                       Bash/Shell (all shells);PHP;SQL
# 1263            C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 1264     Bash/Shell (all shells);C;C#;C++;Delphi;PowerS...
# 1265     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1268     HTML/CSS;Java;JavaScript;Kotlin;PowerShell;Pyt...
# 1269          C#;HTML/CSS;JavaScript;Python;SQL;TypeScript
# 1271            C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 1272     Bash/Shell (all shells);C;C++;MATLAB;PowerShel...
# 1274                Bash/Shell (all shells);PHP;Python;SQL
# 1275             Elixir;HTML/CSS;JavaScript;SQL;TypeScript
# 1276                           HTML/CSS;JavaScript;PHP;SQL
# 1277             HTML/CSS;JavaScript;Python;SQL;TypeScript
# 1278                                                 Swift
# 1279               Bash/Shell (all shells);Java;Python;SQL
# 1280                   Ada;Assembly;C;C#;C++;Python;Zephyr
# 1284     Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1287     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1289                                                C#;SQL
# 1290                                     C++;MATLAB;Python
# 1291     Assembly;Bash/Shell (all shells);C;HTML/CSS;Ja...
# 1292                          C#;JavaScript;PowerShell;SQL
# 1294     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1296         Dart;Go;HTML/CSS;JavaScript;Python;TypeScript
# 1298     Bash/Shell (all shells);Go;Groovy;HTML/CSS;Jav...
# 1299        C;C#;C++;HTML/CSS;Java;JavaScript;Python;R;SQL
# 1304     Bash/Shell (all shells);C;C++;JavaScript;Lisp;...
# 1305                    Bash/Shell (all shells);Python;SQL
# 1306                          JavaScript;Python;TypeScript
# 1307                                               SQL;VBA
# 1308                    HTML/CSS;JavaScript;SQL;TypeScript
# 1309     Bash/Shell (all shells);HTML/CSS;Julia;MATLAB;...
# 1312     Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 1314                    HTML/CSS;JavaScript;SQL;TypeScript
# 1317                            C#;VBA;Visual Basic (.Net)
# 1318     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1319        C#;HTML/CSS;JavaScript;Kotlin;Swift;TypeScript
# 1320                                    Prolog;Python;Rust
# 1321                        HTML/CSS;JavaScript;TypeScript
# 1323                                                   NaN
# 1324     Bash/Shell (all shells);Groovy;HTML/CSS;JavaSc...
# 1325     Assembly;Bash/Shell (all shells);C;C++;Julia;P...
# 1330                  HTML/CSS;JavaScript;Python;R;SQL;VBA
# 1335     Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 1339     Bash/Shell (all shells);HTML/CSS;OCaml;Python;SQL
# 1345     C#;HTML/CSS;JavaScript;PowerShell;SQL;VBA;Visu...
# 1348     Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
# 1349                        Java;JavaScript;SQL;TypeScript
# 1350                                                  Rust
# 1352      C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript
# 1353                        HTML/CSS;JavaScript;TypeScript
# 1357     C#;Groovy;HTML/CSS;Java;JavaScript;OCaml;Power...
# 1363      Bash/Shell (all shells);HTML/CSS;Java;JavaScript
# 1364      C#;HTML/CSS;JavaScript;PowerShell;SQL;TypeScript
# 1369     Groovy;HTML/CSS;Java;JavaScript;Scala;SQL;Type...
# 1373                     Java;JavaScript;PowerShell;Python
# 1376     Bash/Shell (all shells);C#;JavaScript;PowerShe...
# 1378                       C#;JavaScript;Python;TypeScript
# 1380                                                  Java
# 1381                                       Java;PowerShell
# 1382         C++;GDScript;Java;Lua;Python;Scala;TypeScript
# 1383     C#;HTML/CSS;Java;JavaScript;Kotlin;PHP;PowerSh...
# 1384     C#;C++;GDScript;Groovy;Haskell;Java;JavaScript...
# 1386                                        Delphi;Go;Ruby
# 1388     C#;C++;Kotlin;Lua;MicroPython;PowerShell;Pytho...
# 1389     C#;C++;HTML/CSS;JavaScript;PowerShell;Ruby;SQL...
# 1390                 C;C++;Go;Nim;Perl;PHP;Python;Rust;SQL
# 1393                                                  Java
# 1395                     C#;HTML/CSS;JavaScript;Python;SQL
# 1396     Bash/Shell (all shells);C;C#;C++;Java;JavaScri...
# 1399                            HTML/CSS;JavaScript;Python
# 1401       Bash/Shell (all shells);C;Go;MicroPython;Python
# 1408     Ada;Apex;Assembly;Bash/Shell (all shells);C;C#...
# 1410                                                   NaN
# 1411                                   HTML/CSS;JavaScript
# 1412                                            JavaScript
# 1414     Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1418     Bash/Shell (all shells);C;C++;Dart;HTML/CSS;Ja...
# 1421                                          C;C++;Python
# 1422     Bash/Shell (all shells);C;Go;HTML/CSS;JavaScri...
# 1423     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1424        C++;Delphi;Java;Lisp;MATLAB;Python;R;Swift;VBA
# 1426           Bash/Shell (all shells);HTML/CSS;Python;SQL
# 1427                                C#;HTML/CSS;TypeScript
# 1428                          HTML/CSS;Java;JavaScript;SQL
# 1433     Bash/Shell (all shells);C++;HTML/CSS;Java;Java...
# 1435                     Bash/Shell (all shells);Go;Python
# 1436                                                Python
# 1437                                              Java;SQL
# 1439                                                    C#
# 1440                                         C;Go;Rust;SQL
# 1442                                                 Swift
# 1446                        HTML/CSS;JavaScript;Python;SQL
# 1450                     Bash/Shell (all shells);Go;Python
# 1451     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1452         Bash/Shell (all shells);JavaScript;Python;SQL
# 1453                                 Groovy;JavaScript;SQL
# 1456     Bash/Shell (all shells);JavaScript;Python;Scal...
# 1457     Bash/Shell (all shells);C#;PowerShell;SQL;Type...
# 1459     Bash/Shell (all shells);GDScript;HTML/CSS;Java...
# 1460                                            Python;SQL
# 1464            HTML/CSS;Java;JavaScript;Kotlin;Python;SQL
# 1466                            Java;JavaScript;Python;SQL
# 1467     Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 1475                    HTML/CSS;JavaScript;SQL;TypeScript
# 1477     Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 1481      Bash/Shell (all shells);Lua;PowerShell;SQL;Swift
# 1483     Bash/Shell (all shells);C++;Go;HTML/CSS;Java;J...
# 1484     Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 1486     Bash/Shell (all shells);C;HTML/CSS;Java;JavaSc...
# 1488     Bash/Shell (all shells);Elixir;Go;HTML/CSS;Jav...
# 1489             HTML/CSS;JavaScript;Python;SQL;TypeScript
# 1491                           C#;Go;PowerShell;Python;SQL
# 1493        C;C++;Go;HTML/CSS;JavaScript;Lisp;Python;R;SQL
# 1494               HTML/CSS;JavaScript;Rust;SQL;TypeScript
# 1495     C;C#;C++;HTML/CSS;Java;JavaScript;Kotlin;PHP;P...
# 1497     Bash/Shell (all shells);C;C++;Dart;Elixir;Java...
# 1499                                            C;HTML/CSS
# 1502                            Elixir;Java;Ruby;Scala;SQL
# 1503              Bash/Shell (all shells);Go;Groovy;Python
# 1506     Bash/Shell (all shells);HTML/CSS;JavaScript;Ty...
# 1507                                Java;JavaScript;Kotlin
# 1514                                   Java;JavaScript;SQL
# 1517     C;C#;C++;GDScript;Go;HTML/CSS;Java;JavaScript;...
# 1518     Groovy;HTML/CSS;Java;JavaScript;PowerShell;SQL...
# 1519     C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 1520     Assembly;Bash/Shell (all shells);C;C++;Go;HTML...
# 1521      Groovy;HTML/CSS;JavaScript;Kotlin;SQL;TypeScript
# 1523                                                   NaN
# 1524     Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1525                                     Python;Rust;Scala
# 1526             C;C++;Dart;HTML/CSS;JavaScript;Python;SQL
# 1529     Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
# 1530                             JavaScript;PHP;TypeScript
# 1532                                      C;C#;Go;Java;PHP
# 1533                          C;C++;JavaScript;Python;Rust
# 1535                                     C#;PowerShell;SQL
# 1536                              C#;JavaScript;TypeScript
# 1538                                      JavaScript;Swift
# 1539                        HTML/CSS;JavaScript;PHP;Python
# 1540                           HTML/CSS;JavaScript;PHP;SQL
# 1545     Bash/Shell (all shells);C#;Dart;HTML/CSS;JavaS...
# 1547     Bash/Shell (all shells);C#;Elixir;Go;HTML/CSS;...
# 1548     Bash/Shell (all shells);C;C++;HTML/CSS;Java;Ja...
# 1551                        HTML/CSS;JavaScript;TypeScript
# 1553                          Bash/Shell (all shells);Java
# 1555            HTML/CSS;JavaScript;PHP;SQL;TypeScript;VBA
# 1557     Bash/Shell (all shells);Fortran;MATLAB;Python;SQL
# 1558                                              C;Python
# 1561     Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 1564          C;C++;Dart;HTML/CSS;JavaScript;Kotlin;Python
# 1569                                Java;JavaScript;Python
# 1570                                              Python;R
# 1573                                C#;HTML/CSS;TypeScript
# 1576                                            Python;SQL
# 1581     Assembly;Bash/Shell (all shells);C;C#;C++;Fort...
# 1582         Bash/Shell (all shells);PowerShell;Python;SQL
# 1584            C#;HTML/CSS;Java;JavaScript;PHP;TypeScript
# 1589           Go;Groovy;Java;JavaScript;Python;TypeScript
# 1592                  Bash/Shell (all shells);Julia;MATLAB
# 1594     Assembly;Bash/Shell (all shells);C;C++;Dart;Go...
# 1598                                            C++;Python
# 1600                Bash/Shell (all shells);Go;Python;Rust
# 1601     C;C++;HTML/CSS;JavaScript;PowerShell;Python;SQ...
# 1602     Bash/Shell (all shells);HTML/CSS;JavaScript;SQ...
# 1603     Assembly;Bash/Shell (all shells);C;C++;SQL;Typ...
# 1604             Assembly;Bash/Shell (all shells);C;Python
# 1605          Bash/Shell (all shells);Elixir;HTML/CSS;Ruby
# 1610                   C++;JavaScript;PHP;Python;SQL;Swift
# 1611                                  C#;JavaScript;Python
# 1613                        Delphi;HTML/CSS;JavaScript;SQL
# 1614     Assembly;C#;C++;HTML/CSS;JavaScript;Python;SQL...
# 1616     Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 1618     Bash/Shell (all shells);C#;C++;HTML/CSS;JavaSc...
# 1620                          Bash/Shell (all shells);Ruby
# 1621                                          C;Python;SQL
# 1622                            Java;JavaScript;Python;SQL
# 1623     C#;C++;Java;JavaScript;Kotlin;Visual Basic (.Net)
# 1625                                                  Perl
# 1627                              C#;JavaScript;TypeScript
# 1631                                       C++;Objective-C
# 1632     C#;HTML/CSS;Java;JavaScript;Perl;PHP;PowerShel...
# 1633                                   Java;Kotlin;PHP;SQL
# 1636               Bash/Shell (all shells);C;MATLAB;Python
# 1637     Assembly;C;C#;GDScript;HTML/CSS;JavaScript;PHP...
# 1638                 HTML/CSS;JavaScript;Python;TypeScript
# 1643                                   HTML/CSS;JavaScript
# 1648     Bash/Shell (all shells);Groovy;Java;Kotlin;Pow...
# 1649                              C#;PowerShell;TypeScript
# 1650                                                   VBA
# 1655     Bash/Shell (all shells);C;C++;Fortran;HTML/CSS...
# 1657     Bash/Shell (all shells);C;C#;C++;HTML/CSS;Java...
# 1660                                                   NaN
# 1664                          C;C++;Python;Rust;TypeScript
# 1665                                               Dart;Go
# 1668     Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 1670                                           C;Go;Python
# 1671         C#;Go;HTML/CSS;JavaScript;Ruby;SQL;TypeScript
# 1672                          JavaScript;Objective-C;Swift
# 1673                                          Python;R;SQL
# 1674               Bash/Shell (all shells);Java;Python;SQL
# 1676     Groovy;Java;JavaScript;Kotlin;Python;Scala;SQL...
# 1681                                                Kotlin
# 1682     C#;HTML/CSS;JavaScript;PHP;PowerShell;SQL;Visu...
# 1683                 C#;HTML/CSS;JavaScript;PowerShell;SQL
# 1684     C;C++;HTML/CSS;Java;JavaScript;Python;SQL;Type...
# 1688     C#;C++;GDScript;HTML/CSS;Java;JavaScript;PHP;P...
# 1694     Bash/Shell (all shells);C++;Go;Groovy;HTML/CSS...
# 1695     Bash/Shell (all shells);HTML/CSS;Java;JavaScri...
# 1696         HTML/CSS;JavaScript;PowerShell;SQL;TypeScript
# 1697                            Bash/Shell (all shells);Go
# 1699     Bash/Shell (all shells);HTML/CSS;JavaScript;Lu...
# 1706     HTML/CSS;JavaScript;PHP;PowerShell;Python;SQL;...
# 1707     Bash/Shell (all shells);JavaScript;PHP;PowerSh...
# 1709     Bash/Shell (all shells);C;Java;JavaScript;Kotl...
# 1711     Bash/Shell (all shells);C;C#;C++;Dart;Go;HTML/...
# 1721                   HTML/CSS;Java;JavaScript;TypeScript
# 1722                    Bash/Shell (all shells);C++;Python
# 1726                 HTML/CSS;JavaScript;Python;TypeScript
# 1727     Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 1728     Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
# 1729     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1730                                                Go;SQL
# 1732     Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 1741                        HTML/CSS;JavaScript;TypeScript
# 1742                                            TypeScript
# 1751                              C#;JavaScript;TypeScript
# 1756                   Bash/Shell (all shells);Groovy;Java
# 1758     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1759                                         C#;Python;SQL
# 1760     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1766                HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 1770             C#;HTML/CSS;JavaScript;PowerShell;SQL;VBA
# 1773     Bash/Shell (all shells);C++;HTML/CSS;Java;Java...
# 1774     Bash/Shell (all shells);C;HTML/CSS;JavaScript;...
# 1776     C;C#;Dart;HTML/CSS;JavaScript;PHP;Python;Solid...
# 1778                                                  Ruby
# 1779                                              Lisp;SQL
# 1782                         C;C++;Fortran;Python;Rust;SQL
# 1784     Bash/Shell (all shells);C#;JavaScript;SQL;Type...
# 1785     Ada;Bash/Shell (all shells);HTML/CSS;JavaScrip...
# 1786                                            Python;SQL
# 1791                              Apex;HTML/CSS;JavaScript
# 1794     Bash/Shell (all shells);C;C#;C++;Cobol;HTML/CS...
# 1795                         C++;Julia;Kotlin;Python;Swift
# 1798         HTML/CSS;JavaScript;PowerShell;SQL;TypeScript
# 1802     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1804     Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
# 1814     Assembly;Bash/Shell (all shells);C;HTML/CSS;Ja...
# 1815                          HTML/CSS;JavaScript;PHP;Ruby
# 1816     Bash/Shell (all shells);C;C#;C++;Go;HTML/CSS;J...
# 1818     Bash/Shell (all shells);C;Groovy;HTML/CSS;Java...
# 1821     C++;Elixir;F#;Kotlin;Objective-C;Swift;TypeScript
# 1824                HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 1827                            C++;JavaScript;Python;Rust
# 1828     Bash/Shell (all shells);C;Clojure;Delphi;Haske...
# 1832                              HTML/CSS;Java;Python;SQL
# 1834       Bash/Shell (all shells);C;JavaScript;Python;SQL
# 1835                  C#;Go;HTML/CSS;JavaScript;Python;SQL
# 1838                HTML/CSS;JavaScript;Julia;Python;R;SQL
# 1839                        Assembly;C;C++;Dart;Python;SQL
# 1841                                                   NaN
# 1843     Bash/Shell (all shells);Java;JavaScript;Kotlin...
# 1845                          C;Go;HTML/CSS;JavaScript;SQL
# 1846                                           C#;GDScript
# 1849     Bash/Shell (all shells);Delphi;Elixir;Go;Kotli...
# 1851                                                     R
# 1853                      C#;C++;JavaScript;SQL;TypeScript
# 1854                                     C++;Delphi;Go;SQL
# 1857                            C;HTML/CSS;Java;Python;SQL
# 1861                  Bash/Shell (all shells);C;Python;SQL
# 1862     Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 1868        HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript
# 1873     Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 1875      Bash/Shell (all shells);Go;JavaScript;TypeScript
# 1876                                             C#;Python
# 1885                Go;HTML/CSS;Java;JavaScript;TypeScript
# 1888     Assembly;Bash/Shell (all shells);C;C#;C++;Java...
# 1889                 HTML/CSS;JavaScript;PowerShell;Python
# 1892         Bash/Shell (all shells);PowerShell;Python;SQL
# 1899     Assembly;Bash/Shell (all shells);Java;JavaScri...
# 1900                                            JavaScript
# 1902              Go;JavaScript;Python;Rust;SQL;TypeScript
# 1904                       C#;Go;JavaScript;SQL;TypeScript
# 1907                 HTML/CSS;JavaScript;Python;TypeScript
# 1909      Assembly;C;C++;HTML/CSS;Lisp;Lua;Python;Rust;SQL
# 1910                                                   NaN
# 1916                            C#;HTML/CSS;JavaScript;SQL
# 1918     Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
# 1919                                               C++;VBA
# 1921     Bash/Shell (all shells);C;C++;Java;JavaScript;...
# 1922                                              Ruby;SQL
# 1932                 Bash/Shell (all shells);C#;Python;SQL
# 1935                 C#;HTML/CSS;JavaScript;SQL;TypeScript
# 1936     C;C++;Groovy;HTML/CSS;JavaScript;Lua;MATLAB;Py...
# 1939     Bash/Shell (all shells);Go;Groovy;HTML/CSS;Jav...
# 1941                                     Assembly;C;Python
# 1947     Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 1949                        HTML/CSS;JavaScript;TypeScript
# 1950                            Bash/Shell (all shells);Go
# 1951                      C;C++;Java;JavaScript;TypeScript
# 1958     C;C#;C++;HTML/CSS;JavaScript;PHP;Python;TypeSc...
# 1959     Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 1960                                                Python
# 1963         Bash/Shell (all shells);JavaScript;Python;SQL
# 1964                    Bash/Shell (all shells);Python;SQL
# 1966                                   Visual Basic (.Net)
# 1967     Bash/Shell (all shells);C;HTML/CSS;Java;JavaSc...
# 1970                          C#;JavaScript;PHP;TypeScript
# 1973                     Go;HTML/CSS;JavaScript;Python;SQL
# 1974           HTML/CSS;JavaScript;Perl;SQL;TypeScript;VBA
# 1976                 HTML/CSS;JavaScript;Python;TypeScript
# 1980     Bash/Shell (all shells);HTML/CSS;JavaScript;Po...
# 1982                                Groovy;Java;JavaScript
# 1987     Assembly;C++;Elixir;Erlang;Go;JavaScript;Kotli...
# 1991                                 JavaScript;TypeScript
# 1996                            C#;HTML/CSS;JavaScript;SQL
# ...
# 62980              Groovy;Java;JavaScript;Python;Scala;SQL
# 62983    C++;HTML/CSS;JavaScript;Python;Rust;SQL;TypeSc...
# 63008    Ada;Bash/Shell (all shells);JavaScript;Ruby;Ty...
# 63011                       C#;SQL;VBA;Visual Basic (.Net)
# 63013                   HTML/CSS;JavaScript;PHP;TypeScript
# 63019                C#;HTML/CSS;PowerShell;SQL;TypeScript
# 63020                                                Swift
# 63044    Bash/Shell (all shells);HTML/CSS;JavaScript;SQ...
# 63073                                                  NaN
# 63078                                                   Go
# 63095    C#;C++;Go;HTML/CSS;Java;JavaScript;SQL;Visual ...
# 63103                  Bash/Shell (all shells);Java;Python
# 63105                C#;HTML/CSS;JavaScript;SQL;TypeScript
# 63108                                                  NaN
# 63118       HTML/CSS;JavaScript;MATLAB;Python;Solidity;SQL
# 63127            Bash/Shell (all shells);Delphi;PowerShell
# 63129              HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 63130    Bash/Shell (all shells);JavaScript;Kotlin;Pyth...
# 63139    Bash/Shell (all shells);Groovy;Java;JavaScript...
# 63143                       Bash/Shell (all shells);Python
# 63147                                         HTML/CSS;PHP
# 63170    Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 63188    Assembly;C;C++;Delphi;Fortran;HTML/CSS;JavaScr...
# 63192                                                  NaN
# 63200    Ada;Apex;Assembly;Bash/Shell (all shells);C;C#...
# 63209                                                  NaN
# 63240                       Go;Java;JavaScript;Python;Ruby
# 63280                                                C;C++
# 63292                                JavaScript;TypeScript
# 63298                                                  NaN
# 63299                    Dart;Kotlin;Python;SQL;TypeScript
# 63316              HTML/CSS;Java;JavaScript;Kotlin;PHP;SQL
# 63319                        HTML/CSS;JavaScript;PHP;Swift
# 63352    Apex;Bash/Shell (all shells);HTML/CSS;Java;Jav...
# 63372    Bash/Shell (all shells);C;C#;C++;Dart;HTML/CSS...
# 63375                            C++;PowerShell;Python;VBA
# 63380                                                  NaN
# 63393            Bash/Shell (all shells);JavaScript;Python
# 63400                                                   C#
# 63404                             Java;JavaScript;Solidity
# 63409    Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 63412                               Dart;Kotlin;Python;SQL
# 63413                          C++;Go;HTML/CSS;Java;Python
# 63437                     HTML/CSS;JavaScript;Julia;Python
# 63444    Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 63449                                        Go;Python;SQL
# 63454                     C;Haskell;JavaScript;Python;Ruby
# 63471                          Bash/Shell (all shells);SQL
# 63476    Bash/Shell (all shells);C++;Groovy;HTML/CSS;Ja...
# 63497                           C;GDScript;HTML/CSS;Python
# 63501    C;C#;C++;Dart;Go;HTML/CSS;Java;JavaScript;PHP;SQL
# 63504                                                   C#
# 63509                             HTML/CSS;Java;JavaScript
# 63522                            HTML/CSS;JavaScript;Swift
# 63524                                                  NaN
# 63527                                          Java;Kotlin
# 63535                       C++;Fortran;Java;MATLAB;Python
# 63543                    C#;HTML/CSS;JavaScript;TypeScript
# 63545                                                  NaN
# 63547                       HTML/CSS;JavaScript;PHP;Python
# 63558            GDScript;Go;HTML/CSS;Java;JavaScript;Perl
# 63563                                               Python
# 63564                C#;C++;HTML/CSS;JavaScript;TypeScript
# 63567                                            Go;Kotlin
# 63572    Bash/Shell (all shells);Elixir;Erlang;HTML/CSS...
# 63587                                                  NaN
# 63588    Assembly;Bash/Shell (all shells);C;C#;C++;Go;H...
# 63593         C#;Delphi;HTML/CSS;JavaScript;SQL;TypeScript
# 63611                          Java;JavaScript;Python;Rust
# 63620                                     C;Go;Java;Python
# 63628    Bash/Shell (all shells);HTML/CSS;JavaScript;Po...
# 63644                                               Python
# 63663                                    Python;TypeScript
# 63667                          Go;Java;Rust;TypeScript;Zig
# 63691    Bash/Shell (all shells);C#;Dart;Objective-C;Po...
# 63696                              HTML/CSS;JavaScript;SQL
# 63697    Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 63709                                PowerShell;Python;SQL
# 63715          Java;JavaScript;Python;Scala;SQL;TypeScript
# 63718                                                C#;Go
# 63719                           Go;Haskell;Java;Python;SQL
# 63721    Bash/Shell (all shells);C#;JavaScript;PowerShe...
# 63726       HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 63728                     C;HTML/CSS;JavaScript;TypeScript
# 63762    Assembly;C;C++;HTML/CSS;JavaScript;Lua;Python;...
# 63771    Bash/Shell (all shells);C;HTML/CSS;JavaScript;...
# 63772                                                  NaN
# 63773                                                  NaN
# 63779          Bash/Shell (all shells);JavaScript;Ruby;SQL
# 63786       Go;HTML/CSS;JavaScript;Solidity;SQL;TypeScript
# 63799                           C#;HTML/CSS;SQL;TypeScript
# 63801                           HTML/CSS;JavaScript;Python
# 63802                                                  NaN
# 63808                                   C#;Java;Python;SQL
# 63809                                               Python
# 63812                                                  NaN
# 63851                     C++;HTML/CSS;Java;JavaScript;SQL
# 63858                                JavaScript;TypeScript
# 63866                    HTML/CSS;JavaScript;Kotlin;Python
# 63874                        HTML/CSS;Java;Python;Rust;SQL
# 63881    Apex;Assembly;Bash/Shell (all shells);C;C#;C++...
# 63899    Assembly;Bash/Shell (all shells);C++;Go;HTML/C...
# 63941                         C#;PowerShell;SQL;TypeScript
# 63948                                                  NaN
# 63971                                                  NaN
# 63975                             HTML/CSS;Java;JavaScript
# 64000                                      MATLAB;Python;R
# 64009    Assembly;C;C#;C++;Erlang;Fortran;Groovy;Java;J...
# 64021                                                  NaN
# 64030    Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 64040                              HTML/CSS;JavaScript;PHP
# 64048    Elixir;Go;Java;JavaScript;PHP;Python;SQL;TypeS...
# 64052      Elixir;Erlang;Go;HTML/CSS;JavaScript;Lua;Python
# 64053                                        C#;Python;SQL
# 64058                                                  NaN
# 64073                                                  NaN
# 64076    Bash/Shell (all shells);HTML/CSS;Java;MATLAB;P...
# 64097                                    C#;PowerShell;SQL
# 64121                                                  NaN
# 64129       HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 64134                                           JavaScript
# 64142                                                  NaN
# 64144                                       C++;JavaScript
# 64150    C#;HTML/CSS;JavaScript;PowerShell;Python;SQL;T...
# 64155                                                  NaN
# 64156                                           TypeScript
# 64168                           HTML/CSS;JavaScript;Python
# 64187                                                  NaN
# 64193                                                  NaN
# 64194                   Bash/Shell (all shells);Python;SQL
# 64196    Bash/Shell (all shells);C#;Dart;HTML/CSS;JavaS...
# 64211                           C++;Dart;Java;Python;Swift
# 64222                                                  NaN
# 64227    Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
# 64228                                        C#;TypeScript
# 64238                                Assembly;C;C++;Python
# 64258                                                  NaN
# 64261                                               Python
# 64266                                 C#;JavaScript;Python
# 64289                                        C#;Python;SQL
# 64299                                                  NaN
# 64301                       HTML/CSS;PowerShell;Python;SQL
# 64302    Bash/Shell (all shells);Go;Java;JavaScript;Pyt...
# 64303                                      C++;Python;Rust
# 64304                                                  NaN
# 64331                  C;C#;C++;Python;Visual Basic (.Net)
# 64333                           C;C++;HTML/CSS;Java;Kotlin
# 64341                                                  NaN
# 64355               Bash/Shell (all shells);PowerShell;SQL
# 64368            HTML/CSS;JavaScript;Python;SQL;TypeScript
# 64382                           HTML/CSS;JavaScript;Python
# 64387    Assembly;Bash/Shell (all shells);C;C#;C++;HTML...
# 64393                                       Ada;JavaScript
# 64394    Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Type...
# 64398    Bash/Shell (all shells);C;C++;Dart;Go;Groovy;H...
# 64408                                                 Java
# 64412                                                  NaN
# 64415                                                  NaN
# 64417                                                  NaN
# 64426                                            Ada;C;C++
# 64429    C;C#;C++;HTML/CSS;Java;JavaScript;Python;Scala...
# 64433                                                 Java
# 64449                                            C#;Python
# 64450                             C#;JavaScript;TypeScript
# 64457    Assembly;C;C#;C++;Go;HTML/CSS;Java;JavaScript;...
# 64468                                                  NaN
# 64472    Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 64474                                                  NaN
# 64476                                                  NaN
# 64478    Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
# 64483                C++;Java;JavaScript;Python;TypeScript
# 64503                             HTML/CSS;Java;PHP;Python
# 64508                           HTML/CSS;JavaScript;Python
# 64515                                                  NaN
# 64516                     C;C++;HTML/CSS;JavaScript;Python
# 64521                                        C;Java;Python
# 64555                                         Julia;Python
# 64568    Bash/Shell (all shells);C;C#;C++;JavaScript;Po...
# 64585                                                  NaN
# 64598                                                  NaN
# 64609    Bash/Shell (all shells);C++;Go;HTML/CSS;Java;J...
# 64625                           Elixir;JavaScript;Ruby;SQL
# 64654    C++;Go;HTML/CSS;Java;JavaScript;Objective-C;Py...
# 64673    Bash/Shell (all shells);C++;Groovy;Java;Kotlin...
# 64680                                           JavaScript
# 64690            C;C++;HTML/CSS;Java;JavaScript;PHP;Python
# 64697                                                  NaN
# 64729                                                  NaN
# 64734         HTML/CSS;Java;JavaScript;Visual Basic (.Net)
# 64737                                                  NaN
# 64749                                             C;C++;Go
# 64753           C;C++;Dart;HTML/CSS;Java;Kotlin;PHP;Python
# 64763    Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 64777                          HTML/CSS;JavaScript;PHP;SQL
# 64783                       HTML/CSS;JavaScript;TypeScript
# 64788                                  HTML/CSS;JavaScript
# 64802                                    Ada;Assembly;C;C#
# 64811                                                  NaN
# 64818                          Go;JavaScript;Ruby;Rust;SQL
# 64828       Bash/Shell (all shells);Elixir;JavaScript;Ruby
# 64848                                 C++;Dart;Kotlin;Ruby
# 64870                                     Ada;Assembly;C++
# 64871                                                Swift
# 64878                  C;HTML/CSS;Java;JavaScript;Perl;SQL
# 64886                 Bash/Shell (all shells);Python;R;SQL
# 64902                                                  NaN
# 64904         C;C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 64912                                                  SQL
# 64918    Bash/Shell (all shells);C#;JavaScript;PHP;Pyth...
# 64919                                          Go;Rust;SQL
# 64933                                    JavaScript;Python
# 64943    C;C#;C++;Elixir;Go;JavaScript;Python;Rust;Type...
# 64944           C++;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 64954                 C++;JavaScript;Python;SQL;TypeScript
# 64959         C#;HTML/CSS;JavaScript;Python;SQL;TypeScript
# 64972                                                  NaN
# 64973                                                  NaN
# 64986    Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 64991    Bash/Shell (all shells);Delphi;Go;HTML/CSS;Jav...
# 64994    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 65000    Bash/Shell (all shells);C++;HTML/CSS;JavaScrip...
# 65015    Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 65017                     C;C++;Java;JavaScript;Python;SQL
# 65022                                                  NaN
# 65036        Bash/Shell (all shells);JavaScript;TypeScript
# 65043                                                Swift
# 65051                                  C;C++;MATLAB;Python
# 65052                           C++;Scala;Swift;TypeScript
# 65066                                    JavaScript;Python
# 65072            Assembly;C;C++;JavaScript;Rust;TypeScript
# 65081    Bash/Shell (all shells);C;HTML/CSS;PowerShell;...
# 65084    Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 65093    Bash/Shell (all shells);C;C++;HTML/CSS;JavaScr...
# 65095    Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 65099                                                  NaN
# 65105    Bash/Shell (all shells);HTML/CSS;JavaScript;Ty...
# 65121                                               Python
# 65123                                       C;HTML/CSS;SQL
# 65132    Bash/Shell (all shells);C;Dart;Go;HTML/CSS;Jav...
# 65134    Apex;C#;C++;HTML/CSS;Java;JavaScript;PowerShel...
# 65144    Bash/Shell (all shells);C;C++;Lua;MicroPython;...
# 65163    Bash/Shell (all shells);C#;HTML/CSS;JavaScript...
# 65171    C#;Go;HTML/CSS;Java;JavaScript;Python;SQL;Type...
# 65174    Ada;C++;HTML/CSS;Java;TypeScript;Visual Basic ...
# 65181                                          C#;GDScript
# 65187                                                  NaN
# 65214    Elixir;HTML/CSS;Java;JavaScript;PowerShell;SQL...
# 65234                                                  NaN
# 65236          C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 65241                                               Kotlin
# 65242            Bash/Shell (all shells);Clojure;Scala;SQL
# 65247                                                  NaN
# 65249           C#;Perl;PowerShell;SQL;Visual Basic (.Net)
# 65252    Bash/Shell (all shells);C;C#;C++;Python;SQL;Ty...
# 65255                                                  NaN
# 65256                        C;C++;Python;Swift;TypeScript
# 65261            HTML/CSS;JavaScript;Python;SQL;TypeScript
# 65265                                                 Dart
# 65268                           C#;HTML/CSS;JavaScript;SQL
# 65269                                                  NaN
# 65270                                            C++;Swift
# 65334    Bash/Shell (all shells);C;C#;C++;Go;HTML/CSS;J...
# 65339    C;C#;C++;Go;HTML/CSS;JavaScript;Objective-C;Py...
# 65366                                                  NaN
# 65371                                    Elixir;PHP;Python
# 65383                                                  NaN
# 65413                                                  NaN
# 65415                                                  NaN
# 65428                                                  NaN
# 65435             C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# Name: LanguageHaveWorkedWith, dtype: object
