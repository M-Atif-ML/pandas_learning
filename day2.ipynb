# %%
import pandas as pd

# %%
df  = pd.read_csv("data/survey_results_public.csv")
schema_df = pd.read_csv("data/survey_results_schema.csv")

# %%
pd.set_option("display.max_rows",114)
pd.set_option("display.max_columns",114)

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
people = {
    "first" : ["Corey","Jane","John"],
    "last"  : ["Schafer","Doe","Doe"],
    "email" : ["Corey@gmail.com","Jane@gmail.com","John@yahoo.com"]
}

# %%
people["email"]
# Out:
# ['Corey@gmail.com', 'Jane@gmail.com', 'John@yahoo.com']

# %%
df = pd.DataFrame(people)

# %%
df # data frame consist of rows and columns
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   John@yahoo.com

# %%
df["first"]
# Out:
# 'Jane'

# %%
df["last"]
# Out:
# 0    Schafer
# 1        Doe
# 2        Doe
# Name: last, dtype: object

# %%
df["email"]
# Out:
# 0    Corey@gmail.com
# 1     Jane@gmail.com
# 2     John@yahoo.com
# Name: email, dtype: object

# %%
type(df["email"]) # key notation
# Out:
# str

# %%
df.email # dot notation
# Out:
# 0    Corey@gmail.com
# 1     Jane@gmail.com
# 2     John@yahoo.com
# Name: email, dtype: object

# %%
df[["last","email"]] # not a series just a filter down data frame
# Out:
#       last            email
# 0  Schafer  Corey@gmail.com
# 1      Doe   Jane@gmail.com
# 2      Doe   John@yahoo.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
for i in range(0,2):
    print(df.iloc[i])
# Out:
# first              Corey
# last             Schafer
# email    Corey@gmail.com
# Name: 0, dtype: object
# first              Jane
# last                Doe
# email    Jane@gmail.com
# Name: 1, dtype: object

# %%
df.iloc[[0,1],[0,2]]
# Out:
#    first            email
# 0  Corey  Corey@gmail.com
# 1   Jane   Jane@gmail.com

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   John@yahoo.com

# %%
df.loc[[0,1],["email","last"]]
# Out:
#              email     last
# 0  Corey@gmail.com  Schafer
# 1   Jane@gmail.com      Doe
