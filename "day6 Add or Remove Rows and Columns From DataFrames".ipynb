# %%
people = {
    "first" : ["Corey","Jane","John"],
    "last"  : ["Schafer","Doe","Doe"],
    "email" : ["Corey@gmail.com","Jane@gmail.com","John@yahoo.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   John@yahoo.com

# %%
# adding removing columns:

df["first"] +" "+ df["last"]
# Out:
# 0    Corey Schafer
# 1         Jane Doe
# 2         John Doe
# dtype: object

# %%
df["full_name"] = df["first"] +" "+ df["last"]

# %%
df
# Out:
#    first     last            email      full_name
# 0  Corey  Schafer  Corey@gmail.com  Corey Schafer
# 1   Jane      Doe   Jane@gmail.com       Jane Doe
# 2   John      Doe   John@yahoo.com       John Doe

# %%
df.drop(columns = ["first","last"],inplace = True)

# %%
df
# Out:
#              email      full_name
# 0  Corey@gmail.com  Corey Schafer
# 1   Jane@gmail.com       Jane Doe
# 2   John@yahoo.com       John Doe

# %%
df["full_name"].str.split(" ",expand = True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df[["first","last"]] = df["full_name"].str.split(" ",expand = True)

# %%
df
# Out:
#              email      full_name  first     last
# 0  Corey@gmail.com  Corey Schafer  Corey  Schafer
# 1   Jane@gmail.com       Jane Doe   Jane      Doe
# 2   John@yahoo.com       John Doe   John      Doe

# %%
# adding and removing in rows
pd.concat([df, pd.DataFrame([{"first": "Tony","last":"stark"},
                             {"first" : "Jose"}])], ignore_index=True)
# Out:
#              email      full_name  first     last
# 0  Corey@gmail.com  Corey Schafer  Corey  Schafer
# 1   Jane@gmail.com       Jane Doe   Jane      Doe
# 2   John@yahoo.com       John Doe   John      Doe
# 3              NaN            NaN   Tony    stark
# 4              NaN            NaN   Jose      NaN

# %%
people = {
    "first" : ["Toney","Steve"],
    "last"  : ["Stark","Roger"],
    "email" : ["IronMan@gmail.com","Cap@gmail.com"]
}
df2  = pd.DataFrame(people)

# %%
df = pd.concat([df,df2],ignore_index = True)

# %%
df
# Out:
#                email      full_name  first     last
# 0    Corey@gmail.com  Corey Schafer  Corey  Schafer
# 1     Jane@gmail.com       Jane Doe   Jane      Doe
# 2     John@yahoo.com       John Doe   John      Doe
# 3  IronMan@gmail.com            NaN  Toney    Stark
# 4      Cap@gmail.com            NaN  Steve    Roger

# %%
df = df.drop(index = 4)

# %%
df
# Out:
#                email      full_name  first     last
# 0    Corey@gmail.com  Corey Schafer  Corey  Schafer
# 1     Jane@gmail.com       Jane Doe   Jane      Doe
# 2     John@yahoo.com       John Doe   John      Doe
# 3  IronMan@gmail.com            NaN  Toney    Stark

# %%
df.drop(index =df[df["last"] == "Doe"].index)
# Out:
#                email      full_name  first     last
# 0    Corey@gmail.com  Corey Schafer  Corey  Schafer
# 3  IronMan@gmail.com            NaN  Toney    Stark

# %%
# 14:15 (part6)
