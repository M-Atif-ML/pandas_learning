# %%
people = {
    "first" : ["Corey","Jane","John"],
    "last"  : ["Schafer","Doe","Doe"],
    "email" : ["Corey@gmail.com","Jane@gmail.com","John@yahoo.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   John@yahoo.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# change the columns
df.columns = ["first_name","fast_name","email"]

# %%
df
# Out:
#   first_name fast_name            email
# 0      Corey   Schafer  Corey@gmail.com
# 1       Jane       Doe   Jane@gmail.com
# 2       John       Doe   John@yahoo.com

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME FAST_NAME            EMAIL
# 0      Corey   Schafer  Corey@gmail.com
# 1       Jane       Doe   Jane@gmail.com
# 2       John       Doe   John@yahoo.com

# %%
df.columns = df.columns.str.replace("_"," ")

# %%
df
# Out:
#   FIRST NAME FAST NAME            EMAIL
# 0      Corey   Schafer  Corey@gmail.com
# 1       Jane       Doe   Jane@gmail.com
# 2       John       Doe   John@yahoo.com

# %%
df.columns = df.columns.str.replace(" ","_")

# %%
df
# Out:
#   FIRST_NAME FAST_NAME            EMAIL
# 0      Corey   Schafer  Corey@gmail.com
# 1       Jane       Doe   Jane@gmail.com
# 2       John       Doe   John@yahoo.com

# %%
df.rename(columns = {"FIRST_NAME":"first"
                    ,"FAST_NAME":"last",
                    "EMAIL" : "email"},inplace = True)

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   John@yahoo.com

# %%
df.loc[2] = ["John","Smith","Smit@gmail.com"]

# %%
df.loc[2,["last","email"]] = ["Doe","Doe@gmail.com"]

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe    Doe@gmail.com

# %%
df.loc[2,"last"] = "Smith"

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John    Smith    Doe@gmail.com

# %%
df.at[2,"last"] = "Doe"

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe    Doe@gmail.com

# %%
# filt = (df["email"] == "Doe@gmail.com")
# df[filt]["last"] = "Smith" # dont use this it will give you warning

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  Corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe    Doe@gmail.com

# %%
filt = (df["email"] == "Doe@gmail.com")
df.loc[filt,"last"] = "Smith"

# %%
df["email"] = df["email"].str.lower() # changle multple rows at same time

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   jane@gmail.com
# 2   John    Smith    doe@gmail.com

# %%
### how to use apply method 
# just simply add any function as argument

# %%
df["email"].apply(len) # apply for series
# Out:
# 0    15
# 1    14
# 2    13
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df["email"] = df["email"].apply(update_email)

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  COREY@GMAIL.COM
# 1   Jane      Doe   JANE@GMAIL.COM
# 2   John    Smith    DOE@GMAIL.COM

# %%
df["email"] = df["email"].apply(lambda string:string.lower())

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   jane@gmail.com
# 2   John    Smith    doe@gmail.com

# %%
# apply for data-frame

# %%
df.apply(len,axis = "columns")
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first              Corey
# last                 Doe
# email    corey@gmail.com
# dtype: object

# %%
df.apply(lambda x:x.min())
# Out:
# first              Corey
# last                 Doe
# email    corey@gmail.com
# dtype: object

# %%
df.applymap(len)
# Out:
# /tmp/ipykernel_6088/1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    first  last  email
# 0      5     7     15
# 1      4     3     14
# 2      4     5     13

# %%
# applymap function which is use to make changes in the whole dataFrame
# this may give you a warning because this method is a bit old you can
# search for another updated method

# %%
df.applymap(str.lower)
# Out:
# /tmp/ipykernel_6088/357608748.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(str.lower)
#    first     last            email
# 0  corey  schafer  corey@gmail.com
# 1   jane      doe   jane@gmail.com
# 2   john    smith    doe@gmail.com

# %%
df["first"].map({"Corey" : "Chris","Jane":"Mary"})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   jane@gmail.com
# 2   John    Smith    doe@gmail.com

# %%
df["first"] = df["first"].replace({"Corey" : "Chris","Jane":"Mary"})

# %%
df
# Out:
#    first     last            email
# 0  Chris  Schafer  corey@gmail.com
# 1   Mary      Doe   jane@gmail.com
# 2   John    Smith    doe@gmail.com

# %%
# stack overflow survey data

# %%
df = pd.read_csv("data/survey_results_public.csv")
schema_df = pd.read_csv("data/survey_results_schema.csv")

# %%
pd.set_option("display.max_columns",df.shape[1])
pd.set_option("display.max_rows",df.shape[0])

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
df.rename(columns = {"CompTotal":"Salary"},inplace = True)

# %%
df["Salary"]
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN
# 33                 NaN
# 34                 NaN
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39                 NaN
# ...

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
schema_df.head()
# Out:
#       qid       qname                                           question  \
# 0    QID2  MainBranch  Which of the following options best describes ...
# 1  QID127         Age                                 What is your age?*
# 2  QID296  Employment  Which of the following best describes your cur...
# 3  QID308  RemoteWork  Which best describes your current work situation?
# 4  QID341       Check  Just checking to make sure you are paying atte...
#
#   force_resp type selector
# 0       True   MC     SAVR
# 1       True   MC     SAVR
# 2       True   MC     MAVR
# 3      False   MC     SAVR
# 4       True   MC     SAVR

# %%
schema_df.set_index("qname",inplace = True)

# %%
schema_df.reset_index(inplace = True)

# %%
df["SOAccount"] = df["SOAccount"].map({"Yes":True,"No":False,"NAN":"NAN"})

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...
